# %% [markdown]
# # Team Dhayanithi

# %% [markdown]
# ## Done by Dhayanithi_T

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Electric_car.csv')

# %%
df
# Out:
#           Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla    Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                        ID.3 Pure      10.0           160
# 2      Polestar                                2       4.7           210
# 3           BMW                              iX3       6.8           180
# 4         Honda                                e       9.5           145
# ..          ...                              ...       ...           ...
# 98       Nissan                      Ariya 63kWh       7.5           160
# 99         Audi    e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan              Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan  Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Battery_Pack Kwh  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 0         460              70.0              161             940         Yes
# 1         270              45.0              167             250         Yes
# 2         400              75.0              181             620         Yes
# 3         360              74.0              206             560         Yes
# 4         170              28.5              168             190         Yes
# ..        ...               ...              ...             ...         ...
# 98        330              63.0              191             440         Yes
# 99        335              86.5              258             540         Yes
# 100       325              63.0              194             440         Yes
# 101       375              87.0              232             450         Yes
# 102       400              95.0              238             480         Yes
#
#     PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro          INR
# 0          AWD  Type 2 CCS      Sedan       D      5      55480  4540988.068
# 1          RWD  Type 2 CCS  Hatchback       C      5      30000  2455473.000
# 2          AWD  Type 2 CCS   Liftback       D      5      56440  4619563.204
# 3          RWD  Type 2 CCS        SUV       D      5      68040  5569012.764
# 4          RWD  Type 2 CCS  Hatchback       B      4      32997  2700774.753
# ..         ...         ...        ...     ...    ...        ...          ...
# 98         FWD  Type 2 CCS  Hatchback       C      5      45000  3683209.500
# 99         AWD  Type 2 CCS        SUV       E      5      96050  7861606.055
# 100        AWD  Type 2 CCS  Hatchback       C      5      50000  4092455.000
# 101        AWD  Type 2 CCS  Hatchback       C      5      65000  5320191.500
# 102        AWD  Type 2 CCS        SUV       E      5      62000  5074644.200
#
# [103 rows x 16 columns]

# %%
df.head()
# Out:
#         Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla  Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                      ID.3 Pure      10.0           160
# 2    Polestar                              2       4.7           210
# 3         BMW                            iX3       6.8           180
# 4       Honda                              e       9.5           145
#
#    Range_Km  Battery_Pack Kwh  Efficiency_WhKm  FastCharge_KmH RapidCharge  \
# 0       460              70.0              161             940         Yes
# 1       270              45.0              167             250         Yes
# 2       400              75.0              181             620         Yes
# 3       360              74.0              206             560         Yes
# 4       170              28.5              168             190         Yes
#
#   PowerTrain    PlugType  BodyStyle Segment  Seats  PriceEuro          INR
# 0        AWD  Type 2 CCS      Sedan       D      5      55480  4540988.068
# 1        RWD  Type 2 CCS  Hatchback       C      5      30000  2455473.000
# 2        AWD  Type 2 CCS   Liftback       D      5      56440  4619563.204
# 3        RWD  Type 2 CCS        SUV       D      5      68040  5569012.764
# 4        RWD  Type 2 CCS  Hatchback       B      4      32997  2700774.753

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             103 non-null    object
#  1   Model             103 non-null    object
#  2   AccelSec          103 non-null    float64
#  3   TopSpeed_KmH      103 non-null    int64
#  4   Range_Km          103 non-null    int64
#  5   Battery_Pack Kwh  103 non-null    float64
#  6   Efficiency_WhKm   103 non-null    int64
#  7   FastCharge_KmH    103 non-null    int64
#  8   RapidCharge       103 non-null    object
#  9   PowerTrain        103 non-null    object
#  10  PlugType          103 non-null    object
#  11  BodyStyle         103 non-null    object
#  12  Segment           103 non-null    object
#  13  Seats             103 non-null    int64
#  14  PriceEuro         103 non-null    int64
#  15  INR               103 non-null    float64
# dtypes: float64(3), int64(6), object(7)
# memory usage: 13.0+ KB

# %%
df.isnull().sum()
# Out:
# Brand               0
# Model               0
# AccelSec            0
# TopSpeed_KmH        0
# Range_Km            0
# Battery_Pack Kwh    0
# Efficiency_WhKm     0
# FastCharge_KmH      0
# RapidCharge         0
# PowerTrain          0
# PlugType            0
# BodyStyle           0
# Segment             0
# Seats               0
# PriceEuro           0
# INR                 0
# dtype: int64

# %%
df.describe()
# Out:
#          AccelSec  TopSpeed_KmH    Range_Km  Battery_Pack Kwh  \
# count  103.000000    103.000000  103.000000        103.000000
# mean     7.390291    179.029126  338.592233         65.343689
# std      3.017027     43.651799  126.078519         29.817532
# min      2.100000    123.000000   95.000000         16.700000
# 25%      5.100000    150.000000  250.000000         43.750000
# 50%      7.300000    160.000000  340.000000         64.000000
# 75%      9.000000    200.000000  400.000000         83.700000
# max     22.400000    410.000000  970.000000        200.000000
#
#        Efficiency_WhKm  FastCharge_KmH       Seats      PriceEuro  \
# count       103.000000      103.000000  103.000000     103.000000
# mean        189.145631      433.495146    4.883495   55860.776699
# std          29.576888      220.488356    0.795834   34110.686225
# min         104.000000        0.000000    2.000000   20129.000000
# 25%         168.000000      255.000000    5.000000   34429.500000
# 50%         180.000000      440.000000    5.000000   45000.000000
# 75%         203.000000      555.000000    5.000000   65000.000000
# max         273.000000      940.000000    7.000000  215000.000000
#
#                 INR
# count  1.030000e+02
# mean   4.572154e+06
# std    2.791929e+06
# min    1.647541e+06
# 25%    2.818024e+06
# 50%    3.683210e+06
# 75%    5.320192e+06
# max    1.759756e+07

# %% [markdown]
# ## Distributing vehicle price above and below INR 4000000

# %%
df['CarName'] = df['Brand'] + '-' + df['Model']
df_1= df.loc[df['INR'] <=4000000]
df_2 = df.loc[df['INR'] >4000000]
t1 = ['Less than INR 4000000']
t2 = ['More thanINR 4000000']

# %%
def train(dataframe):
    sns.countplot(x=dataframe['PowerTrain'])
    plt.title('Count Plot of a Powertrain')
    plt.xlabel('PowerTrain')
    plt.ylabel('Count')
    
train(df)

# %%
def bodystyle(dataframe):
    plt.figure(figsize=(10,5))
    sns.countplot(x='BodyStyle', data=dataframe, hue='PowerTrain')
    plt.title('Count plot of Body Style')
    plt.xlabel('Body Style')
    plt.ylabel('Count')
    plt.show()
    
bodystyle(df)

# %% [markdown]
# ## Range of Vehicles

# %%
def range(dataframe, price):
    plt.figure(figsize=(20,5))
    sns.set_theme(style="whitegrid")
    sns.barplot('Model', 'Range_Km', data=df, hue=df['PowerTrain'])
    plt.title('''Range(Km) of EV's costing{}'''.format(price))
    plt.ylabel('Range(Km)')
    plt.xlabel('Model')
    plt.xticks(rotation = 90)
    plt.show()

range(df_1, t1)
range(df_2, t2)

# %% [markdown]
# ## Range - Battery Pack

# %%
#range-batterypack
def range_batterypack(dataframe, text):
    fig = plt.figure(figsize=(20,5))
    a1= plt.subplot()
    a1.bar(dataframe["CarName"], dataframe["Range_Km"], label='Range (Km)', color='cyan')
    plt.legend(loc= "upper left", bbox_to_anchor=(0,1.105))
    a2 = a1.twinx()
    a2.scatter(dataframe["CarName"], dataframe["Battery_Pack Kwh"], label= "Battery Pack", color= 'black')
    plt.title('''RANGE(Km) vs BATTERY PACK CAPACITY (kwh) of EV's costing {}'''.format(text), fontsize=12)
    a1.set_xlabel('Models', size= 16)
    a1.set_ylabel('Range (Km)', color = 'blue')
    a2.set_ylabel('Battery Pack Capacity (Kwh)', color='black')
    plt.legend(loc='upper left', bbox_to_anchor=(0,1))
    a1.set_xticklabels(df_1['CarName'], rotation = 'vertical')
    plt.show()
    
range_batterypack(df_1, t1)
range_batterypack(df_2, t2)

# %% [markdown]
# ## Range - Vehicle Price

# %%
#Range - Price
def range_price(dataframe, text):
    fig = plt.figure(figsize=(20, 5))
    a1 = plt.subplot()
    a1.bar(dataframe['CarName'], dataframe['Range_Km'], label='Range (Km)', color='pink')
    plt.legend(loc='upper left', bbox_to_anchor = (0, 1.1))
    a2= a1.twinx()
    a2.scatter(dataframe['CarName'], dataframe['INR'], label = 'Price', color = 'black')
    plt.title('''RANGE (Km) vs PRICE(INR) OF EV's COSTING {}'''.format(text), fontsize=16)
    a1.set_xlabel('Models', size=16)
    a1.set_ylabel('Range (Km)', color = 'red')
    a2.set_ylabel('Price(INR)', color= 'black')
    plt.legend(loc = 'upper left', bbox_to_anchor = (0,1.1))
    a1.set_xticklabels(df_1['CarName'], rotation = 'vertical')
    plt.show()
    
range_price(df_1, t1)
range_price(df_2, t2)

# %% [markdown]
# ## Acceleration(0-100km/hr)

# %%
#Accelaration(0-100km/hr)
def acc(dataframe, text):
    plt.figure(figsize=(20,5))
    sns.set_theme(style="darkgrid")
    sns.barplot('CarName', 'AccelSec', data=df, hue=df['PowerTrain'])
    plt.title('''Acceleration 0-100 Km of EV's costing {}'''.format(text), fontsize=16)
    plt.ylabel('Acceleration (Seconds)')
    plt.xlabel('Model')
    plt.xticks(rotation = 90)
    plt.show()
    
acc(df_1, t1)
acc(df_2, t2)

# %% [markdown]
# ## Fast Charging Vehicles

# %%
# Fast Charging data
def fastcharge(dataframe, price):
    plt.figure(figsize=(20, 5))
    sns.set_theme(style="whitegrid")
    sns.barplot('CarName', 'FastCharge_KmH', data=df, color = 'yellow')
    plt.title('''Fast Charging of EV's costing {}'''.format(price), fontsize = 16)
    plt.ylabel('Charging Capacity (KmH)')
    plt.xlabel('Model')
    plt.xticks(rotation=90)
    plt.show()
    
fastcharge(df_1, t1)    
fastcharge(df_2, t2)

# %% [markdown]
# ## Vehicles to buy under INR 40,00000 with max range(Km)

# %%
pd.set_option('display.max_columns', None)
top_range_1 = df_1.sort_values(by= 'Range_Km', ascending= False)
top_range_1[['CarName', 'Range_Km', 'Battery_Pack Kwh', 'INR', 'RapidCharge']]
# Out:
#                               CarName  Range_Km  Battery_Pack Kwh  \
# 15              Volkswagen-ID.3 Pro S       440              77.0
# 37                      CUPRA-el-Born       425              77.0
# 25                    Volkswagen-ID.4       420              77.0
# 54                  Skoda-Enyaq iV 80       420              77.0
# 12       Hyundai-Kona Electric 64 kWh       400              64.0
# 72                 Skoda-Enyaq iV 80X       400              77.0
# 89                 Skoda-Enyaq iV vRS       400              77.0
# 87      Tesla-Cybertruck Single Motor       390             100.0
# 31                  Kia-e-Niro 64 kWh       370              64.0
# 45                 Kia-E -Soul 64 kWh       365              64.0
# 84         Ford-Mustang Mach-E SR RWD       360              88.0
# 26                Volkswagen-ID.3 Pro       350              58.0
# 39                       Mercedes-EQA       350              66.5
# 81                Volkswagen-ID.3 1st       340              58.0
# 95    Volkswagen-ID.3 Pro Performance       340              58.0
# 50                          Aiways-U5       335              63.0
# 47                      Opel-Ampera-e       335              58.0
# 46                      Opel-Ampera-e       335              58.0
# 98                 Nissan-Ariya 63kWh       330              63.0
# 35                     Nissan-Leaf e+       325              56.0
# 90                  Skoda-Enyaq iV 60       320              58.0
# 32              Renault-Zoe ZE50 R110       315              52.0
# 38              Renault-Zoe ZE50 R135       310              52.0
# 8   Tesla-Model 3 Standard Range Plus       310              50.0
# 22                  Skoda-Enyaq iV 50       290              52.0
# 7                       Peugeot-e-208       275              45.0
# 20                       Opel-Corsa-e       275              45.0
# 1                Volkswagen-ID.3 Pure       270              45.0
# 61              Renault-Zoe ZE40 R110       255              41.0
# 53                       Opel-Mokka-e       255              45.0
# 41       Hyundai-Kona Electric 39 kWh       255              39.0
# 94              Fiat-500e Convertible       250              23.8
# 29                 Peugeot-e-2008 SUV       250              45.0
# 57             DS-3 Crossback E-Tense       250              45.0
# 59                       Citroen-e-C4       250              45.0
# 86                Fiat-500e Hatchback       250              37.3
# 14             Hyundai-IONIQ Electric       250              38.3
# 28                      BMW-i3 120 Ah       235              37.9
# 76                  Kia-e-Niro 39 kWh       235              39.0
# 71                     BMW-i3s 120 Ah       230              37.9
# 96                  Kia-e-Soul 39 kWh       230              39.0
# 75                          Sono-Sion       225              35.0
# 11                        Nissan-Leaf       220              36.0
# 18                           MG-ZS EV       220              42.5
# 17                   Volkswagen-e-Up!       195              36.8
# 43                   Skoda-CITIGOe iV       195              36.8
# 44                  SEAT-Mii Electric       195              32.3
# 67              Nissan-e-NV200 Evalia       190              38.0
# 6                   Volkswagen-e-Golf       190              35.8
# 19                     Mini-Cooper SE       185              28.9
# 34                        Mazda-MX-30       180              30.0
# 4                             Honda-e       170              28.5
# 56                    Honda-e Advance       170              28.5
# 69          Renault-Kangoo Maxi ZE 33       160              31.0
# 58                  Renault-Twingo ZE       130              21.3
# 83              Smart-EQ fortwo coupe       100              16.7
# 78                   Smart-EQ forfour        95              16.7
# 92             Smart-EQ fortwo cabrio        95              16.7
#
#             INR RapidCharge
# 15  3350574.758         Yes
# 37  3683209.500         Yes
# 25  3683209.500         Yes
# 54  3273964.000         Yes
# 12  3339034.035         Yes
# 72  3683209.500         Yes
# 89  3887832.250         Yes
# 87  3683209.500         Yes
# 31  3118859.956         Yes
# 45  3015075.297         Yes
# 84  3838722.790         Yes
# 26  2701020.300         Yes
# 39  3683209.500         Yes
# 81  3191050.862         Yes
# 95  2911781.733         Yes
# 50  2951232.999         Yes
# 47  3429968.385         Yes
# 46  3429968.385         Yes
# 98  3683209.500         Yes
# 35  3047814.937         Yes
# 90  3069341.250         Yes
# 32  2552382.334         Yes
# 38  2711906.230         Yes
# 8   3796161.258         Yes
# 22  2864718.500         Yes
# 7   2429444.986         Yes
# 20  2385573.869         Yes
# 1   2455473.000         Yes
# 61  2392776.589         Yes
# 53  2864718.500         Yes
# 41  2780495.776         Yes
# 94  3102080.890         Yes
# 29  2812416.925         Yes
# 57  3062957.020         Yes
# 59  3273964.000         Yes
# 86  2856533.590         Yes
# 14  2820438.137         Yes
# 28  3111657.235         Yes
# 76  2815609.040         Yes
# 71  3398865.727         Yes
# 96  2711906.230         Yes
# 75  2087152.050         Yes
# 11  2392776.589         Yes
# 18  2455473.000         Yes
# 17  1753289.571         Yes
# 43  2008085.819         Yes
# 44  1647540.534         Yes
# 67  2721155.179         Yes
# 6   2610986.290         Yes
# 19  2593061.337         Yes
# 34  2672045.719         Yes
# 4   2700774.753         Yes
# 56  2940101.521         Yes
# 69  3110265.800          No
# 58  2029039.189          No
# 83  1750506.702          No
# 78  1803135.673          No
# 92  2010623.142          No

# %% [markdown]
# ## Vehicles with best Acceleration under INR 40,00000

# %%
pd.set_option('display.max_columns', None)
acceleration_1 = df_1.sort_values(by= 'AccelSec')
acceleration_1[['CarName', 'AccelSec', 'Range_Km', 'PowerTrain', 'Battery_Pack Kwh', 'INR']]
# Out:
#                               CarName  AccelSec  Range_Km PowerTrain  \
# 39                       Mercedes-EQA       5.0       350        AWD
# 8   Tesla-Model 3 Standard Range Plus       5.6       310        RWD
# 89                 Skoda-Enyaq iV vRS       6.2       400        AWD
# 37                      CUPRA-el-Born       6.5       425        RWD
# 84         Ford-Mustang Mach-E SR RWD       6.6       360        RWD
# 71                     BMW-i3s 120 Ah       6.9       230        RWD
# 87      Tesla-Cybertruck Single Motor       7.0       390        RWD
# 72                 Skoda-Enyaq iV 80X       7.0       400        AWD
# 95    Volkswagen-ID.3 Pro Performance       7.3       340        RWD
# 81                Volkswagen-ID.3 1st       7.3       340        RWD
# 28                      BMW-i3 120 Ah       7.3       235        RWD
# 47                      Opel-Ampera-e       7.3       335        FWD
# 46                      Opel-Ampera-e       7.3       335        FWD
# 19                     Mini-Cooper SE       7.3       185        FWD
# 35                     Nissan-Leaf e+       7.3       325        FWD
# 98                 Nissan-Ariya 63kWh       7.5       330        FWD
# 25                    Volkswagen-ID.4       7.5       420        RWD
# 31                  Kia-e-Niro 64 kWh       7.8       370        FWD
# 45                 Kia-E -Soul 64 kWh       7.9       365        FWD
# 12       Hyundai-Kona Electric 64 kWh       7.9       400        FWD
# 15              Volkswagen-ID.3 Pro S       7.9       440        RWD
# 11                        Nissan-Leaf       7.9       220        FWD
# 7                       Peugeot-e-208       8.1       275        FWD
# 20                       Opel-Corsa-e       8.1       275        FWD
# 18                           MG-ZS EV       8.2       220        FWD
# 56                    Honda-e Advance       8.3       170        RWD
# 29                 Peugeot-e-2008 SUV       8.5       250        FWD
# 53                       Opel-Mokka-e       8.5       255        FWD
# 57             DS-3 Crossback E-Tense       8.7       250        FWD
# 54                  Skoda-Enyaq iV 80       8.8       420        RWD
# 90                  Skoda-Enyaq iV 60       9.0       320        RWD
# 50                          Aiways-U5       9.0       335        FWD
# 94              Fiat-500e Convertible       9.0       250        FWD
# 75                          Sono-Sion       9.0       225        FWD
# 26                Volkswagen-ID.3 Pro       9.0       350        RWD
# 86                Fiat-500e Hatchback       9.0       250        FWD
# 34                        Mazda-MX-30       9.0       180        FWD
# 4                             Honda-e       9.5       170        RWD
# 38              Renault-Zoe ZE50 R135       9.5       310        FWD
# 6                   Volkswagen-e-Golf       9.6       190        FWD
# 59                       Citroen-e-C4       9.7       250        FWD
# 14             Hyundai-IONIQ Electric       9.7       250        FWD
# 76                  Kia-e-Niro 39 kWh       9.8       235        FWD
# 96                  Kia-e-Soul 39 kWh       9.9       230        FWD
# 41       Hyundai-Kona Electric 39 kWh       9.9       255        FWD
# 22                  Skoda-Enyaq iV 50      10.0       290        RWD
# 1                Volkswagen-ID.3 Pure      10.0       270        RWD
# 32              Renault-Zoe ZE50 R110      11.4       315        FWD
# 61              Renault-Zoe ZE40 R110      11.4       255        FWD
# 83              Smart-EQ fortwo coupe      11.6       100        RWD
# 17                   Volkswagen-e-Up!      11.9       195        FWD
# 92             Smart-EQ fortwo cabrio      11.9        95        RWD
# 44                  SEAT-Mii Electric      12.3       195        FWD
# 43                   Skoda-CITIGOe iV      12.3       195        FWD
# 58                  Renault-Twingo ZE      12.6       130        RWD
# 78                   Smart-EQ forfour      12.7        95        RWD
# 67              Nissan-e-NV200 Evalia      14.0       190        FWD
# 69          Renault-Kangoo Maxi ZE 33      22.4       160        FWD
#
#     Battery_Pack Kwh          INR
# 39              66.5  3683209.500
# 8               50.0  3796161.258
# 89              77.0  3887832.250
# 37              77.0  3683209.500
# 84              88.0  3838722.790
# 71              37.9  3398865.727
# 87             100.0  3683209.500
# 72              77.0  3683209.500
# 95              58.0  2911781.733
# 81              58.0  3191050.862
# 28              37.9  3111657.235
# 47              58.0  3429968.385
# 46              58.0  3429968.385
# 19              28.9  2593061.337
# 35              56.0  3047814.937
# 98              63.0  3683209.500
# 25              77.0  3683209.500
# 31              64.0  3118859.956
# 45              64.0  3015075.297
# 12              64.0  3339034.035
# 15              77.0  3350574.758
# 11              36.0  2392776.589
# 7               45.0  2429444.986
# 20              45.0  2385573.869
# 18              42.5  2455473.000
# 56              28.5  2940101.521
# 29              45.0  2812416.925
# 53              45.0  2864718.500
# 57              45.0  3062957.020
# 54              77.0  3273964.000
# 90              58.0  3069341.250
# 50              63.0  2951232.999
# 94              23.8  3102080.890
# 75              35.0  2087152.050
# 26              58.0  2701020.300
# 86              37.3  2856533.590
# 34              30.0  2672045.719
# 4               28.5  2700774.753
# 38              52.0  2711906.230
# 6               35.8  2610986.290
# 59              45.0  3273964.000
# 14              38.3  2820438.137
# 76              39.0  2815609.040
# 96              39.0  2711906.230
# 41              39.0  2780495.776
# 22              52.0  2864718.500
# 1               45.0  2455473.000
# 32              52.0  2552382.334
# 61              41.0  2392776.589
# 83              16.7  1750506.702
# 17              36.8  1753289.571
# 92              16.7  2010623.142
# 44              32.3  1647540.534
# 43              36.8  2008085.819
# 58              21.3  2029039.189
# 78              16.7  1803135.673
# 67              38.0  2721155.179
# 69              31.0  3110265.800

# %% [markdown]
# ## Vehicles with Maximum Efficiency

# %%
pd.set_option('display.max_columns', None)
efficiency = df.sort_values(by = 'Efficiency_WhKm')
efficiency[['CarName', 'Efficiency_WhKm', 'Range_Km', 'PowerTrain', 'Battery_Pack Kwh', 'INR']]
# Out:
#                                CarName  Efficiency_WhKm  Range_Km PowerTrain  \
# 49                       Lightyear-One              104       575        AWD
# 8    Tesla-Model 3 Standard Range Plus              153       310        RWD
# 14              Hyundai-IONIQ Electric              153       250        FWD
# 41        Hyundai-Kona Electric 39 kWh              154       255        FWD
# 19                      Mini-Cooper SE              156       185        FWD
# ..                                 ...              ...       ...        ...
# 99  Audi-e-tron S Sportback 55 quattro              258       335        AWD
# 68         Tesla-Cybertruck Dual Motor              261       460        AWD
# 33          Tesla-Cybertruck Tri Motor              267       750        AWD
# 91            Audi-e-tron S 55 quattro              270       320        AWD
# 85               Mercedes-EQV 300 Long              273       330        FWD
#
#     Battery_Pack Kwh           INR
# 49              60.0  1.219552e+07
# 8               50.0  3.796161e+06
# 14              38.3  2.820438e+06
# 41              39.0  2.780496e+06
# 19              28.9  2.593061e+06
# ..               ...           ...
# 99              86.5  7.861606e+06
# 68             120.0  4.501700e+06
# 33             200.0  6.138682e+06
# 91              86.5  7.677446e+06
# 85              90.0  5.781084e+06
#
# [103 rows x 6 columns]
